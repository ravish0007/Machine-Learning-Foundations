# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d
from sklearn.model_selection import train_test_split

# %%
spectf1=pd.read_csv('C:/Users/Venu/Desktop/HDS/SPECTF_test.csv', names=["Target","F1R","F1S","F2R","F2S","F3R","F3S","F4R","F4S","F5R","F5S","F6R","F6S","F7R","F7S","F8R","F8S","F9R","F9S","F10R","F10S","F11R","F11S","F12R","F12S","F13R","F13S","F14R","F14S","F15R","F15S","F16R","F16S","F17R","F17S","F18R","F18S","F19R","F19S","F20R","F20S","F21R","F21S","F22R","F22S"])
spectf1
# Out:
#      Target  F1R  F1S  F2R  F2S  F3R  F3S  F4R  F4S  F5R  ...   F18R  F18S  \
# 0         1   67   68   73   78   65   63   67   60   63  ...     61    56
# 1         1   75   74   71   71   62   58   70   64   71  ...     66    62
# 2         1   83   64   66   67   67   74   74   72   64  ...     67    64
# 3         1   72   66   65   65   64   61   71   78   73  ...     69    68
# 4         1   62   60   69   61   63   63   70   68   70  ...     66    66
# 5         1   68   63   67   67   65   72   74   72   70  ...     70    70
# 6         1   80   76   77   76   67   68   71   76   69  ...     57    58
# 7         1   68   63   62   58   60   57   69   78   59  ...     66    67
# 8         1   77   61   71   69   70   66   57   55   67  ...     48    40
# 9         1   69   68   73   74   62   67   74   73   67  ...     61    65
# 10        1   65   69   70   71   56   63   63   70   44  ...     71    73
# ...

# %%
spectf2=pd.read_csv('C:/Users/Venu/Desktop/HDS/SPECTF_train.csv', names=["Target","F1R","F1S","F2R","F2S","F3R","F3S","F4R","F4S","F5R","F5S","F6R","F6S","F7R","F7S","F8R","F8S","F9R","F9S","F10R","F10S","F11R","F11S","F12R","F12S","F13R","F13S","F14R","F14S","F15R","F15S","F16R","F16S","F17R","F17S","F18R","F18S","F19R","F19S","F20R","F20S","F21R","F21S","F22R","F22S"])
spectf2
# Out:
#     Target  F1R  F1S  F2R  F2S  F3R  F3S  F4R  F4S  F5R  ...   F18R  F18S  \
# 0        1   59   52   70   67   73   66   72   61   58  ...     66    56
# 1        1   72   62   69   67   78   82   74   65   69  ...     65    71
# 2        1   71   62   70   64   67   64   79   65   70  ...     73    70
# 3        1   69   71   70   78   61   63   67   65   59  ...     61    61
# 4        1   70   66   61   66   61   58   69   69   72  ...     67    69
# 5        1   57   69   68   75   69   74   73   71   57  ...     63    58
# 6        1   69   66   62   75   67   71   72   76   69  ...     69    70
# 7        1   61   60   60   62   64   72   68   67   74  ...     66    66
# 8        1   65   62   67   68   65   67   71   71   64  ...     67    63
# 9        1   74   73   72   79   66   61   76   66   65  ...     64    62
# 10       1   70   69   60   62   58   60   71   77   69  ...     68    67
# 11       1   67   66   65   77   66   70   72   72   72  ...     72    71
# ...

# %%
spectf1.keys()
# Out:
# Index(['Target', 'F1R', 'F1S', 'F2R', 'F2S', 'F3R', 'F3S', 'F4R', 'F4S', 'F5R',
#        'F5S', 'F6R', 'F6S', 'F7R', 'F7S', 'F8R', 'F8S', 'F9R', 'F9S', 'F10R',
#        'F10S', 'F11R', 'F11S', 'F12R', 'F12S', 'F13R', 'F13S', 'F14R', 'F14S',
#        'F15R', 'F15S', 'F16R', 'F16S', 'F17R', 'F17S', 'F18R', 'F18S', 'F19R',
#        'F19S', 'F20R', 'F20S', 'F21R', 'F21S', 'F22R', 'F22S'],
#       dtype='object')

# %%
correlation=spectf1.corr('pearson')
correlation
# Out:
#           Target       F1R       F1S       F2R       F2S       F3R       F3S  \
# Target  1.000000 -0.033205 -0.072310 -0.047347 -0.100783 -0.162407 -0.218370
# F1R    -0.033205  1.000000  0.601643  0.380365  0.376806  0.184712  0.208528
# F1S    -0.072310  0.601643  1.000000  0.271874  0.455517  0.055241  0.317336
# F2R    -0.047347  0.380365  0.271874  1.000000  0.601705  0.166304  0.149028
# F2S    -0.100783  0.376806  0.455517  0.601705  1.000000  0.094517  0.226083
# F3R    -0.162407  0.184712  0.055241  0.166304  0.094517  1.000000  0.710749
# F3S    -0.218370  0.208528  0.317336  0.149028  0.226083  0.710749  1.000000
# F4R    -0.084463  0.599774  0.415818  0.300404  0.239487  0.262919  0.350626
# F4S    -0.117129  0.424983  0.519327  0.141069  0.233756  0.394523  0.656415
# F5R    -0.109763  0.549938  0.455041  0.246003  0.310953  0.231966  0.251063
# F5S    -0.111054  0.411568  0.629239  0.216476  0.359562  0.184040  0.342526
# ...

# %%
correlation['Target'].sort_values()
# Out:
# F21S     -0.233921
# F22R     -0.224858
# F3S      -0.218370
# F22S     -0.213390
# F13S     -0.204077
# F21R     -0.201578
# F13R     -0.187924
# F20S     -0.180498
# F8R      -0.167806
# F7S      -0.163484
# F3R      -0.162407
# F20R     -0.158235
# F8S      -0.157609
# F15S     -0.124314
# F18S     -0.122409
# F17S     -0.121160
# F16S     -0.120838
# F4S      -0.117129
# F15R     -0.112002
# F10R     -0.111721
# F12R     -0.111261
# F5S      -0.111054
# F5R      -0.109763
# F12S     -0.108912
# F18R     -0.103840
# F2S      -0.100783
# F7R      -0.094505
# F6S      -0.090615
# F4R      -0.084463
# F17R     -0.084401
# F11R     -0.084087
# F1S      -0.072310
# F19S     -0.069405
# F10S     -0.068210
# F9R      -0.065156
# F19R     -0.060936
# F16R     -0.052769
# F9S      -0.051781
# F6R      -0.047473
# F2R      -0.047347
# F11S     -0.043544
# F14R     -0.043510
# F1R      -0.033205
# F14S     -0.022509
# Target    1.000000
# Name: Target, dtype: float64

# %%
x1=spectf1['F21S']
x2=spectf1['F22R']
y=spectf1['Target']

# %%
x1=np.array(x1)
x2=np.array(x2)
y=np.array(y)

# %%
x1=(x1-x1.min())/(x1.max()-x1.min())
x2=(x2-x2.min())/(x2.max()-x2.min())
y=(y-y.min())/(y.max()-y.min())

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.plot(x1, x2, y, 'g.')

# %%
x1.size
# Out:
# 187

# %%
x2.size
# Out:
# 187

# %%
correlation=spectf2.corr('pearson')
correlation
# Out:
#           Target       F1R       F1S       F2R       F2S       F3R       F3S  \
# Target  1.000000  0.134916 -0.153489 -0.264282 -0.357876 -0.032195 -0.256404
# F1R     0.134916  1.000000  0.459985  0.245528  0.174106  0.035401 -0.048772
# F1S    -0.153489  0.459985  1.000000  0.298719  0.426246 -0.022179  0.143192
# F2R    -0.264282  0.245528  0.298719  1.000000  0.689725  0.194395  0.142732
# F2S    -0.357876  0.174106  0.426246  0.689725  1.000000  0.100561  0.268939
# F3R    -0.032195  0.035401 -0.022179  0.194395  0.100561  1.000000  0.391196
# F3S    -0.256404 -0.048772  0.143192  0.142732  0.268939  0.391196  1.000000
# F4R    -0.043057  0.259527  0.141931  0.198584  0.097297  0.298236  0.069102
# F4S    -0.244278  0.119893  0.527893  0.123432  0.277806 -0.190983  0.250682
# F5R    -0.001694  0.256918  0.175323  0.263416  0.281373  0.108280 -0.112457
# F5S    -0.230602  0.198825  0.446105  0.280271  0.313164  0.036442  0.038185
# ...

# %%
correlation['Target'].sort_values()
# Out:
# F20S     -0.526152
# F15S     -0.488084
# F13S     -0.410055
# F21S     -0.394695
# F12S     -0.381477
# F13R     -0.378735
# F14S     -0.378530
# F22R     -0.378077
# F20R     -0.375311
# F2S      -0.357876
# F21R     -0.353954
# F11S     -0.332094
# F22S     -0.327979
# F16S     -0.323664
# F15R     -0.323575
# F8S      -0.291540
# F7S      -0.290655
# F2R      -0.264282
# F3S      -0.256404
# F10S     -0.246964
# F12R     -0.246207
# F4S      -0.244278
# F5S      -0.230602
# F16R     -0.221958
# F18S     -0.211905
# F8R      -0.190110
# F19S     -0.182488
# F17R     -0.178427
# F9S      -0.174335
# F6S      -0.156661
# F1S      -0.153489
# F17S     -0.150225
# F14R     -0.146302
# F7R      -0.134440
# F10R     -0.114378
# F11R     -0.096580
# F6R      -0.090127
# F18R     -0.081470
# F9R      -0.074458
# F4R      -0.043057
# F3R      -0.032195
# F19R     -0.017983
# F5R      -0.001694
# F1R       0.134916
# Target    1.000000
# Name: Target, dtype: float64

# %%
x1_train=spectf2['F21S']
x2_train=spectf2['F22R']
y_train=spectf2['Target']

x1_train=np.array(x1_train)
x2_train=np.array(x2_train)
y_train=np.array(y_train)

# %%
x1_train=(x1_train-x1_train.min())/(x1_train.max()-x1_train.min())
x2_train=(x2_train-x2_train.min())/(x2_train.max()-x2_train.min())
y_train=(y_train-y_train.min())/(y_train.max()-y_train.min())

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.plot(x1_train, x2_train, y_train, 'g.')

# %%
def hypothesis(a,b,c,x1,x2):
    return (1/(1+np.exp(-(a*x1+b*x2+c))))

# %%
def error(a,b,c,x1,x2,y):
    e=0
    m=len(x1)
    for i in range(m):
        e+=-(y[i]*np.log(hypothesis(a,b,c,x1[i],x2[i])))-((1-y[i])*np.log(1-hypothesis(a,b,c,x1[i],x2[i])))
        
    return (1/m)*e

# %%
def step_gradient(a,b,c,x1,x2,y,learning_rate):
    grad_a=0
    grad_b=0
    grad_c=0
    
    m=len(x1)
    
    for i in range(m):
        grad_a+=(hypothesis(a,b,c,x1[i],x2[i])-y[i])*x1[i]
        grad_b+=(hypothesis(a,b,c,x1[i],x2[i])-y[i])*x2[i]
        grad_c+=(hypothesis(a,b,c,x1[i],x2[i])-y[i])
        
    a=a-(grad_a*learning_rate)
    b=b-(grad_b*learning_rate)
    c=c-(grad_c*learning_rate)
    
    return a,b,c

# %%
def descend(init_a,init_b,init_c,x1,x2,y,learning_rate,iterations):
    a=init_a
    b=init_b
    c=init_c
    
    for i in range(iterations):
        e=error(a,b,c,x1,x2,y)
        
        if i % 1000==0:
            print(f"error: {e},a:{a},b:{b},c:{c}")
            
        a,b,c=step_gradient(a,b,c,x1,x2,y,learning_rate)
        
    return a,b,c

# %%
init_a=-9.618624893165268
init_b=-4.078440515759424
init_c=12.724708986265295
iterations=10000
learning_rate=0.001

# %%
final_a,final_b,final_c=descend(init_a,init_b,init_c,x1,x2,y,learning_rate,iterations)
# Out:
# error: 0.22274423243247174,a:-9.618624893165268,b:-4.078440515759424,c:12.724708986265295
# error: 0.2227442324324174,a:-9.618627455137009,b:-4.078440020516343,c:12.724710814895708
# error: 0.2227442324323672,a:-9.618629917593156,b:-4.07843954497509,c:12.724712572818811
# error: 0.2227442324323208,a:-9.618632284402771,b:-4.078439088334095,c:12.724714262758916
# error: 0.22274423243227814,a:-9.618634559284255,b:-4.078438649825758,c:12.724715887336172
# error: 0.2227442324322385,a:-9.618636745811134,b:-4.078438228714806,c:12.724717449070322
# error: 0.22274423243220198,a:-9.618638847417804,b:-4.078437824296984,c:12.724718950384661
# error: 0.2227442324321682,a:-9.618640867404949,b:-4.078437435897568,c:12.724720393609607
# error: 0.22274423243213698,a:-9.618642808944758,b:-4.078437062870117,c:12.724721780986266
# error: 0.22274423243210817,a:-9.618644675086024,b:-4.078436704595125,c:12.7247231146698

# %%
fig=plt.figure()
ax=fig.add_subplot(1,1,1,projection='3d')
ax.view_init(45,45)

ax.plot3D(x1,x2,y,'r.')
ax.plot3D(x1,x2, hypothesis(init_a, init_b, init_c, x1, x2),'g.')
ax.set_xlabel("F21S")
ax.set_ylabel("F22R")
ax.set_zlabel("TARGET")
plt.show()

# %%
error(final_a,final_b,final_c,x1,x2,y)
# Out:
# 0.22274423243208158

# %%
error(final_a,final_b,final_c,x1_train,x2_train,y_train)
# Out:
# 1.236208513325976

# %%
def accuracy(a,b,c,x1,x2,y):
    correct=0
    m=len(x1)
    
    for i in range(m):
        pred=hypothesis(a,b,c,x1[i],x2[i])
        
        if pred > 0.5:
            z=1
        else:
            z=0
            
        if y[i]==z:
            correct+=1
            
    print(f"Accuracy:{correct/len(y)}")

# %%
accuracy(final_a,final_b,final_c,x1,x2,y)
# Out:
# Accuracy:0.9144385026737968
